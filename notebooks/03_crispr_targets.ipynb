# %% [markdown]
# # CRISPR target workflow
#
# 1. List stored guides from the database.
# 2. (Optional) Call `ingest.crispr.save_guides_for_gene` with a real Ensembl id to fetch CDS and scan for SpCas9 sites (requires network).

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT / "src"))

from salmo_omlas.db import connect
from salmo_omlas.config import get_db_path
from salmo_omlas.query.crispr_queries import list_crispr_for_gene, rank_genes_for_pathway_crispr

conn = connect(get_db_path())
list_crispr_for_gene(conn, "TLR3")

# %%
rank_genes_for_pathway_crispr(conn, "immune")

# %%
# Example (network required): design guides for a salmon Ensembl gene id
# from salmo_omlas.ingest import crispr as ingest_crispr
# ingest_crispr.save_guides_for_gene(conn, "ENSSSAG00000000001", max_guides=10)
