# %% [markdown]
# # Immune pathways and genes
#
# Use `query_process` to find GO / KEGG annotations matching immune-related keywords.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT / "src"))

from salmo_omlas.db import connect
from salmo_omlas.config import get_db_path
from salmo_omlas.query.core import query_process

conn = connect(get_db_path())
res = query_process(conn, "immune")
res["processes"].head(20)

# %%
res["genes"][["symbol", "ensembl_gene_id", "process_name", "evidence"]].drop_duplicates()

# %% [markdown]
# After full ingestion, expand keywords to `interferon`, `TLR`, `cytokine`, etc.
